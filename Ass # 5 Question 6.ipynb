# %%
def shoplist():
        quitshop = False
        shoppinglist = []

        while (quitshop == False):
            print (" ")
            print("Your shopping list contains ")
            print (" ")
            for item in shoppinglist:
                print(item)
                

            print (" ")
            print ("Menu")
            print (" ")
            print ("0 = add multiple items to list")
            print ("1 = add item to list")
            print ("2 = remove specific item")
            print ("3 = quit")
            userchoice = int(input ("Please enter the option you want to proceed with "))

            if (userchoice ==0):
                print("You chose option 0")
                
                additem = ""
    
                while additem != "stop":
                    additem = input ("Please enter item for list: ")

                    if additem != "stop" and "additem":
                        shoppinglist.append(additem)
                    
            elif (userchoice ==1):
                
                print("You chose option 1")
                additem = input ("Please enter an item you want to add: ")
                shoppinglist.append(additem)
            elif (userchoice ==2):
                print("You chose option 2")
                positiontode1 = int(input("Which item would you like to delete? (enter a number)"))
                del(shoppinglist[positiontode1])
            elif (userchoice ==3):
                print("You have chosen to quit the program")
                quit
                quitshop = True
                 
            else:
                print ("error")
                print ("Try again")

if __name__== "__main__":
    shoplist()
# Out:
#
# Your shopping list contains
#
#
# Menu
#
# 0 = add multiple items to list
# 1 = add item to list
# 2 = remove specific item
# 3 = quit
# Please enter the option you want to proceed with 0
# You chose option 0
# Please enter item for list: Wheat
# Please enter item for list: Rice'
# Please enter item for list: Chocolate
# Please enter item for list: Salt
# Please enter item for list: Apples
# Please enter item for list: stop
#
# Your shopping list contains
#
# Wheat
# Rice'
# Chocolate
# Salt
# Apples
#
# Menu
#
# 0 = add multiple items to list
# 1 = add item to list
# 2 = remove specific item
# 3 = quit
# Please enter the option you want to proceed with 2
# You chose option 2
# Which item would you like to delete? (enter a number)2
#
# Your shopping list contains
#
# Wheat
# Rice'
# Salt
# Apples
#
# Menu
#
# 0 = add multiple items to list
# 1 = add item to list
# 2 = remove specific item
# 3 = quit
# Please enter the option you want to proceed with 1
# You chose option 1
# Please enter an item you want to add: Rice
#
# Your shopping list contains
#
# Wheat
# Rice'
# Salt
# Apples
# Rice
#
# Menu
#
# 0 = add multiple items to list
# 1 = add item to list
# 2 = remove specific item
# 3 = quit
# Please enter the option you want to proceed with 3
# You have chosen to quit the program
